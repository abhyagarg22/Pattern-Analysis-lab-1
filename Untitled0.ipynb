# %% [markdown]
# <a href="https://colab.research.google.com/github/abhyagarg22/Pattern-Analysis-lab-1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
print("PyTorch Version:", torch.__version__)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
X, Y = np.mgrid[-4.0:4:0.01, -4.0:4:0.01]
x = torch.Tensor(X)
y = torch.Tensor(Y)
x = x.to(device)
y = y.to(device)
z = torch.exp(-(x**2+y**2)/2.0)
import matplotlib.pyplot as plt
plt.imshow(z.cpu().numpy())#Updated!
plt.tight_layout()
plt.show()
# Out:
# PyTorch Version: 2.6.0+cu124

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a grid of X and Y values
X, Y = np.mgrid[-4.0:4.0:0.01, -4.0:4.0:0.01]

# Calculate the 2D Gaussian function
Z = np.exp(-(X**2 + Y**2) / 2.0)

# Plot the Gaussian
plt.imshow(Z, cmap='viridis')
plt.title('2D Gaussian Function (Numpy)')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.tight_layout()
plt.show()

# %%
import torch
import matplotlib.pyplot as plt

# Select device (GPU if available, else CPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Create coordinate grids using torch
x_vals = torch.arange(-4.0, 4.0, 0.01, device=device)
y_vals = torch.arange(-4.0, 4.0, 0.01, device=device)
X, Y = torch.meshgrid(x_vals, y_vals, indexing='ij')

# Calculate the 2D Gaussian function
Z = torch.exp(-(X**2 + Y**2) / 2.0)

# Move to CPU for plotting
Z_cpu = Z.cpu().numpy()

# Plot the Gaussian
plt.imshow(Z_cpu, cmap='viridis')
plt.title('2D Gaussian Function (PyTorch)')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.tight_layout()
plt.show()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# Choose device: GPU if available, otherwise CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Create meshgrid coordinates
X, Y = np.mgrid[-4.0:4.0:0.01, -4.0:4.0:0.01]

# Convert to PyTorch tensors
x = torch.tensor(X, dtype=torch.float32, device=device)
y = torch.tensor(Y, dtype=torch.float32, device=device)

# 2D sine function: angle depends on both x and y
# You can tweak frequency_x and frequency_y for more or fewer stripes
frequency_x = 2.0
frequency_y = 0.0
z = torch.sin(frequency_x * x + frequency_y * y)

# Move data back to CPU and plot
plt.imshow(z.cpu().numpy(), cmap='grey', origin='lower')
plt.colorbar(label='Sine value')
plt.title("2D Sine Function Stripes")
plt.tight_layout()
plt.show()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# Choose device: GPU if available, otherwise CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Create meshgrid coordinates
X, Y = np.mgrid[-4.0:4.0:0.01, -4.0:4.0:0.01]

# Convert to PyTorch tensors
x = torch.tensor(X, dtype=torch.float32, device=device)
y = torch.tensor(Y, dtype=torch.float32, device=device)

# 2D sine function: angle depends on both x and y
# You can tweak frequency_x and frequency_y for more or fewer stripes
frequency_x = 2.0
frequency_y = 0.0
z = torch.cos(frequency_x * x + frequency_y * y)

# Move data back to CPU and plot
plt.imshow(z.cpu().numpy(), cmap='grey', origin='lower')
plt.colorbar(label='Cosine value')
plt.title("2D Cosine Function Stripes")
plt.tight_layout()
plt.show()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# Select device (GPU if available)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Create meshgrid for coordinates
X, Y = np.mgrid[-4.0:4.0:0.01, -4.0:4.0:0.01]
x = torch.tensor(X, dtype=torch.float32, device=device)
y = torch.tensor(Y, dtype=torch.float32, device=device)

# ----- Step 1: Create Gaussian -----
gaussian = torch.exp(-(x**2 + y**2) / 2.0)

# ----- Step 2: Create 2D sine function -----
frequency_x = 3.0  # change to adjust stripe frequency in x
frequency_y = 0.0  # set to nonzero for tilted stripes
sine_func = torch.sin(frequency_x * x + frequency_y * y)

# ----- Step 3: Multiply Gaussian and sine (modulation) -----
gabor = gaussian * sine_func

# Gabor
plt.imshow(gabor.cpu().numpy(), cmap='seismic', origin='lower')
plt.title("Gabor Filter (Gaussian × Sine)")
plt.colorbar()

plt.tight_layout()
plt.show()

# %%
import torch
import numpy as np
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
Y, X = np.mgrid[-1.3:1.3:0.005, -2:1:0.005]
x = torch.Tensor(X)
y = torch.Tensor(Y)
z = torch.complex(x, y) #important!
zs = z.clone() #Updated!
ns = torch.zeros_like(z)
z = z.to(device)
zs = zs.to(device)
ns = ns.to(device)
for i in range(200):
#Compute the new values of z: z^2 + x
  zs_ = zs*zs + z
#Have we diverged with this new value?
  not_diverged = torch.abs(zs_) < 4.0
#Update variables to compute
  ns += not_diverged
  zs = zs_
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(16,10))
def processFractal(a):
  """Display an array of iteration counts as a
colorful picture of a fractal."""
  a_cyclic = (6.28*a/20.0).reshape(list(a.shape)+[1])
  img = np.concatenate([10+20*np.cos(a_cyclic),
  30+50*np.sin(a_cyclic),
  155-80*np.cos(a_cyclic)], 2)
  img[a==a.max()] = 0
  a = img
  a = np.uint8(np.clip(a, 0, 255))
  return a
plt.imshow(processFractal(ns.cpu().numpy()))
plt.tight_layout(pad=0)
plt.show()
# Out:
# /tmp/ipython-input-2966742068.py:32: ComplexWarning: Casting complex values to real discards the imaginary part
#   a = np.uint8(np.clip(a, 0, 255))

# %%
import torch
import matplotlib.pyplot as plt

# Parameters
width, height = 1024, 1024  # resolution
max_iter = 200  # max iterations
xmin, xmax = -2.0, 1.0
ymin, ymax = -1.5, 1.5
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Create a grid of complex numbers
x = torch.linspace(xmin, xmax, width, device=device)
y = torch.linspace(ymin, ymax, height, device=device)
X, Y = torch.meshgrid(x, y, indexing='ij')
C = X + 1j * Y
Z = torch.zeros_like(C)
output = torch.zeros(C.shape, dtype=torch.int32, device=device)

# Mandelbrot iteration
for i in range(max_iter):
    mask = torch.abs(Z) <= 2
    Z[mask] = Z[mask] ** 2 + C[mask]
    output[mask] = i

# Convert to CPU and plot
plt.imshow(output.cpu().T, cmap='hot', extent=(xmin, xmax, ymin, ymax))
plt.xlabel('Re')
plt.ylabel('Im')
plt.title('Mandelbrot Set')
plt.show()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# Device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Grid definition (same as original)
Y, X = np.mgrid[-1.3:1.3:0.005, -2:1:0.005]
x = torch.tensor(X, dtype=torch.float32, device=device)
y = torch.tensor(Y, dtype=torch.float32, device=device)
z = torch.complex(x, y)

# Iteration setup
zs = z.clone()
ns = torch.zeros_like(x, dtype=torch.int32, device=device)

# Mandelbrot iteration
max_iter = 200
for i in range(max_iter):
    zs_ = zs * zs + z
    not_diverged = torch.abs(zs_) < 4.0
    ns += not_diverged
    zs = zs_

# Coloring function (same as original)
def processFractal(a):
    """Display an array of iteration counts as a colorful picture of a fractal."""
    a_cyclic = (6.28 * a / 20.0).reshape(list(a.shape) + [1])
    img = np.concatenate([
        10 + 20 * np.cos(a_cyclic),
        30 + 50 * np.sin(a_cyclic),
        155 - 80 * np.cos(a_cyclic)], 2)
    img[a == a.max()] = 0
    return np.uint8(np.clip(img, 0, 255))

# Plot
fig = plt.figure(figsize=(16, 10))
plt.imshow(processFractal(ns.cpu().numpy()))
plt.tight_layout(pad=0)
plt.show()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# Device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Grid definition (same as original)
# Zoomed-in window
Y, X = np.mgrid[-1.3:1.3:0.005, -2:1:0.005]
x = torch.tensor(X, dtype=torch.float32, device=device)
y = torch.tensor(Y, dtype=torch.float32, device=device)
z = torch.complex(x, y)
c = torch.tensor(-0.7 + 0.27015j, device=device)
# Iteration setup
zs = z.clone()
ns = torch.zeros_like(x, dtype=torch.int32, device=device)

# Mandelbrot iteration
max_iter = 200
for i in range(max_iter):
    zs_ = zs * zs + c
    not_diverged = torch.abs(zs_) < 4.0
    ns += not_diverged
    zs = zs_

# Coloring function (same as original)
def processFractal(a):
    """Display an array of iteration counts as a colorful picture of a fractal."""
    a_cyclic = (6.28 * a / 20.0).reshape(list(a.shape) + [1])
    img = np.concatenate([
        10 + 20 * np.cos(a_cyclic),
        30 + 50 * np.sin(a_cyclic),
        155 - 80 * np.cos(a_cyclic)], 2)
    img[a == a.max()] = 0
    return np.uint8(np.clip(img, 0, 255))

# Plot
fig = plt.figure(figsize=(16, 10))
plt.imshow(processFractal(ns.cpu().numpy()))
plt.tight_layout(pad=0)
plt.show()
